# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Create a DataFrame with the experimental data
data = {
    'Oven_Temperature': ['Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'High', 'High', 'High'],
    'Baking_Time': ['Short', 'Short', 'Short', 'Long', 'Long', 'Long', 'Short', 'Short', 'Short', 'Long', 'Long', 'Long'],
    'Quality_Score': [6, 7, 6, 8, 7, 8, 5, 6, 5, 9, 8, 9]
}

df = pd.DataFrame(data)
df
# Out:
#    Oven_Temperature Baking_Time  Quality_Score
# 0               Low       Short              6
# 1               Low       Short              7
# 2               Low       Short              6
# 3               Low        Long              8
# 4               Low        Long              7
# 5               Low        Long              8
# 6              High       Short              5
# 7              High       Short              6
# 8              High       Short              5
# 9              High        Long              9
# 10             High        Long              8
# 11             High        Long              9

# %%
# Perform Two-Way ANOVA
model = ols('Quality_Score ~ C(Oven_Temperature) + C(Baking_Time) + C(Oven_Temperature):C(Baking_Time)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Display the ANOVA table
print(anova_table)
# Out:
#                                           sum_sq   df             F    PR(>F)
# C(Oven_Temperature)                 4.160009e-31  1.0  1.248003e-30  1.000000
# C(Baking_Time)                      1.633333e+01  1.0  4.900000e+01  0.000113
# C(Oven_Temperature):C(Baking_Time)  3.000000e+00  1.0  9.000000e+00  0.017072
# Residual                            2.666667e+00  8.0           NaN       NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Interaction plot
sns.pointplot(x='Oven_Temperature', y='Quality_Score', hue='Baking_Time', data=df, ci=None)
plt.title('Interaction Plot: Oven Temperature vs Baking Time')
plt.xlabel('Oven Temperature')
plt.ylabel('Quality Score')
plt.show()
# Out:
# C:\Users\askpr\AppData\Local\Temp\ipykernel_22752\1721448929.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Oven_Temperature', y='Quality_Score', hue='Baking_Time', data=df, ci=None)
